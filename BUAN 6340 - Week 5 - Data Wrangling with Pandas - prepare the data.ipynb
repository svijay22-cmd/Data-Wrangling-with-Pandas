# %% [markdown]
# # Data Wrangling with Pandas - prepare the data

# %%
import pandas as pd

# %%
# read data from a pickle file
fires = pd.read_pickle('fires_cleaned.pkl')
fires.head()
# Out:
#        fire_name  fire_year state discovery_date contain_date  acres_burned
# 16         POWER       2004    CA     2004-10-06   2004-10-21       16823.0
# 17         FREDS       2004    CA     2004-10-13   2004-10-17        7700.0
# 25      BACHELOR       2004    NM     2004-07-20   2004-07-20          10.0
# 37    HOWARD GAP       2005    NC     2005-01-27   2005-01-28          50.3
# 39  AUSTIN CREEK       2005    NC     2005-02-12   2005-02-13         125.0

# %%
fires.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 274123 entries, 16 to 1880441
# Data columns (total 6 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   fire_name       128667 non-null  object
#  1   fire_year       274123 non-null  int64
#  2   state           274123 non-null  category
#  3   discovery_date  274123 non-null  datetime64[ns]
#  4   contain_date    137376 non-null  datetime64[ns]
#  5   acres_burned    274123 non-null  float64
# dtypes: category(1), datetime64[ns](2), float64(1), int64(1), object(1)
# memory usage: 12.8+ MB

# %% [markdown]
# ### Working with string, numeric, and datetime columns

# %%
# add a new column (as object data type)
fires['state_obj'] = fires['state'].astype(object)

# %%
fires.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 274123 entries, 16 to 1880441
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   fire_name       128667 non-null  object
#  1   fire_year       274123 non-null  int64
#  2   state           274123 non-null  category
#  3   discovery_date  274123 non-null  datetime64[ns]
#  4   contain_date    137376 non-null  datetime64[ns]
#  5   acres_burned    274123 non-null  float64
#  6   state_obj       274123 non-null  object
# dtypes: category(1), datetime64[ns](2), float64(1), int64(1), object(2)
# memory usage: 14.9+ MB

# %%
# create a new column that combining fire_name and state_obj columns
fires['fire_name_state_obj'] = fires['fire_name'] + "_" + fires['state_obj']

# %%
fires.head()
# Out:
#        fire_name  fire_year state discovery_date contain_date  acres_burned  \
# 16         POWER       2004    CA     2004-10-06   2004-10-21       16823.0
# 17         FREDS       2004    CA     2004-10-13   2004-10-17        7700.0
# 25      BACHELOR       2004    NM     2004-07-20   2004-07-20          10.0
# 37    HOWARD GAP       2005    NC     2005-01-27   2005-01-28          50.3
# 39  AUSTIN CREEK       2005    NC     2005-02-12   2005-02-13         125.0
#
#    state_obj fire_name_state_obj
# 16        CA            POWER_CA
# 17        CA            FREDS_CA
# 25        NM         BACHELOR_NM
# 37        NC       HOWARD GAP_NC
# 39        NC     AUSTIN CREEK_NC

# %%
# create a new column that combining fire_name and state columns
fires['fire_name_state'] = fires['fire_name'] +"_"+ fires['state']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [8], in <cell line: 2>()
#       1 # create a new column that combining fire_name and state columns
# ----> 2 fires['fire_name_state'] = fires['fire_name'] +"_"+ fires['state']
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops\common.py:70, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      66             return NotImplemented
#      68 other = item_from_zerodim(other)
# ---> 70 return method(self, other)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\arraylike.py:100, in OpsMixin.__add__(self, other)
#      98 @unpack_zerodim_and_defer("__add__")
#      99 def __add__(self, other):
# --> 100     return self._arith_method(other, operator.add)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py:5639, in Series._arith_method(self, other, op)
#    5637 def _arith_method(self, other, op):
#    5638     self, other = ops.align_method_SERIES(self, other)
# -> 5639     return base.IndexOpsMixin._arith_method(self, other, op)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\base.py:1295, in IndexOpsMixin._arith_method(self, other, op)
#    1292 rvalues = ensure_wrapped_if_datetimelike(rvalues)
#    1294 with np.errstate(all="ignore"):
# -> 1295     result = ops.arithmetic_op(lvalues, rvalues, op)
#    1297 return self._construct_result(result, name=res_name)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:216, in arithmetic_op(left, right, op)
#     203 # NB: We assume that extract_array and ensure_wrapped_if_datetimelike
#     204 #  have already been called on `left` and `right`,
#     205 #  and `maybe_prepare_scalar_for_op` has already been called on `right`
#     206 # We need to special-case datetime64/timedelta64 dtypes (e.g. because numpy
#     207 # casts integer dtypes to timedelta64 when operating with timedelta64 - GH#22390)
#     209 if (
#     210     should_extension_dispatch(left, right)
#     211     or isinstance(right, (Timedelta, BaseOffset, Timestamp))
#    (...)
#     214     # Timedelta/Timestamp and other custom scalars are included in the check
#     215     # because numexpr will fail on it, see GH#31457
# --> 216     res_values = op(left, right)
#     217 else:
#     218     # TODO we should handle EAs consistently and move this check before the if/else
#     219     # (https://github.com/pandas-dev/pandas/issues/41165)
#     220     _bool_arith_check(op, left, right)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\arrays\categorical.py:1530, in Categorical.__array_ufunc__(self, ufunc, method, *inputs, **kwargs)
#    1526         return result
#    1528 # for all other cases, raise for now (similarly as what happens in
#    1529 # Series.__array_prepare__)
# -> 1530 raise TypeError(
#    1531     f"Object with dtype {self.dtype} cannot perform "
#    1532     f"the numpy op {ufunc.__name__}"
#    1533 )
#
# TypeError: Object with dtype category cannot perform the numpy op add

# %%
# convert the object columns to string data types first and combine
fires['fire_name_state'] = fires['fire_name'].astype(str) +"_"+ fires['state'].astype(str)

# %%
fires.head()
# Out:
#        fire_name  fire_year state discovery_date contain_date  acres_burned  \
# 16         POWER       2004    CA     2004-10-06   2004-10-21       16823.0
# 17         FREDS       2004    CA     2004-10-13   2004-10-17        7700.0
# 25      BACHELOR       2004    NM     2004-07-20   2004-07-20          10.0
# 37    HOWARD GAP       2005    NC     2005-01-27   2005-01-28          50.3
# 39  AUSTIN CREEK       2005    NC     2005-02-12   2005-02-13         125.0
#
#    state_obj fire_name_state_obj  fire_name_state
# 16        CA            POWER_CA         POWER_CA
# 17        CA            FREDS_CA         FREDS_CA
# 25        NM         BACHELOR_NM      BACHELOR_NM
# 37        NC       HOWARD GAP_NC    HOWARD GAP_NC
# 39        NC     AUSTIN CREEK_NC  AUSTIN CREEK_NC

# %%
fires[['fire_year','state','fire_name']].head()
# Out:
#     fire_year state     fire_name
# 16       2004    CA         POWER
# 17       2004    CA         FREDS
# 25       2004    NM      BACHELOR
# 37       2005    NC    HOWARD GAP
# 39       2005    NC  AUSTIN CREEK

# %% [markdown]
# ### Pandas dt accessor
#
# * **year**
# * **month**
# * **day**
# * **quarter**
# * **days**
# * **seconds**

# %%
# add a numeric month column derived from a datetime column
fires['fire_month'] = fires.discovery_date.dt.month

# %%
# add a numeric column derived from a datetime calculation
fires['days_burning'] = (fires.contain_date - fires.discovery_date).dt.days

# %%
fires['month_burning'] = fires['days_burning']/30
fires.head()
# Out:
#        fire_name  fire_year state discovery_date contain_date  acres_burned  \
# 16         POWER       2004    CA     2004-10-06   2004-10-21       16823.0
# 17         FREDS       2004    CA     2004-10-13   2004-10-17        7700.0
# 25      BACHELOR       2004    NM     2004-07-20   2004-07-20          10.0
# 37    HOWARD GAP       2005    NC     2005-01-27   2005-01-28          50.3
# 39  AUSTIN CREEK       2005    NC     2005-02-12   2005-02-13         125.0
#
#    state_obj fire_name_state_obj  fire_name_state  fire_month  days_burning  \
# 16        CA            POWER_CA         POWER_CA          10          15.0
# 17        CA            FREDS_CA         FREDS_CA          10           4.0
# 25        NM         BACHELOR_NM      BACHELOR_NM           7           0.0
# 37        NC       HOWARD GAP_NC    HOWARD GAP_NC           1           1.0
# 39        NC     AUSTIN CREEK_NC  AUSTIN CREEK_NC           2           1.0
#
#     month_burning
# 16       0.500000
# 17       0.133333
# 25       0.000000
# 37       0.033333
# 39       0.033333

# %% [markdown]
# ### Pandas str accessor
#
# * **count(str)**
# * **lower(str)**
# * **upper(str)**
# * **title(str)**
# * **lstrip(str)**
# * **rstrip(str)**
# * **strip(str)**
# * **startswith(str)**
# * **endswith(str)**
# * **find(str)**
# * **replace(old,new)**
# * **join(sequence)**

# %%
# modify a column derived from string data
fires['fire_name'] = fires.fire_name.str.title()

# %%
# add a column derived from string data
fires['full_name'] = 'The ' + fires.fire_name + ' Fire ' \
                   + '(' + fires.fire_year.astype(str) + ')'

# %%
fires.head()
# Out:
#        fire_name  fire_year state discovery_date contain_date  acres_burned  \
# 16         Power       2004    CA     2004-10-06   2004-10-21       16823.0
# 17         Freds       2004    CA     2004-10-13   2004-10-17        7700.0
# 25      Bachelor       2004    NM     2004-07-20   2004-07-20          10.0
# 37    Howard Gap       2005    NC     2005-01-27   2005-01-28          50.3
# 39  Austin Creek       2005    NC     2005-02-12   2005-02-13         125.0
#
#    state_obj fire_name_state_obj  fire_name_state  fire_month  days_burning  \
# 16        CA            POWER_CA         POWER_CA          10          15.0
# 17        CA            FREDS_CA         FREDS_CA          10           4.0
# 25        NM         BACHELOR_NM      BACHELOR_NM           7           0.0
# 37        NC       HOWARD GAP_NC    HOWARD GAP_NC           1           1.0
# 39        NC     AUSTIN CREEK_NC  AUSTIN CREEK_NC           2           1.0
#
#     month_burning                     full_name
# 16       0.500000         The Power Fire (2004)
# 17       0.133333         The Freds Fire (2004)
# 25       0.000000      The Bachelor Fire (2004)
# 37       0.033333    The Howard Gap Fire (2005)
# 39       0.033333  The Austin Creek Fire (2005)

# %%
# acres burned per day
fires['acres_per_day'] = fires.dropna().acres_burned / fires.dropna().days_burning

# %%
fires[['fire_name','full_name','acres_burned','days_burning','acres_per_day']].head()
# Out:
#        fire_name                     full_name  acres_burned  days_burning  \
# 16         Power         The Power Fire (2004)       16823.0          15.0
# 17         Freds         The Freds Fire (2004)        7700.0           4.0
# 25      Bachelor      The Bachelor Fire (2004)          10.0           0.0
# 37    Howard Gap    The Howard Gap Fire (2005)          50.3           1.0
# 39  Austin Creek  The Austin Creek Fire (2005)         125.0           1.0
#
#     acres_per_day
# 16    1121.533333
# 17    1925.000000
# 25            inf
# 37      50.300000
# 39     125.000000

# %%
fires[['state','days_burning']].head()
# Out:
#    state  days_burning
# 16    CA          15.0
# 17    CA           4.0
# 25    NM           0.0
# 37    NC           1.0
# 39    NC           1.0

# %%
fires.shape
# Out:
# (274123, 14)

# %% [markdown]
# ### Pandas transform() method
#
# * **transform()** -> Adds summary values to each row.
#
# Parameters:
#
# * **func** -> The function to apply.
# * **axis** -> 0 (the default) for rows; 1 for columns.

# %%
# add mean days_burning by state to each row
fires.groupby('state')['days_burning'].transform(func='mean')
# Out:
# 16         5.387197
# 17         5.387197
# 25         6.085806
# 37         1.015474
# 39         1.015474
#              ...
# 1880387    5.387197
# 1880399    5.387197
# 1880411    5.387197
# 1880419    5.387197
# 1880441    5.387197
# Name: days_burning, Length: 274123, dtype: float64

# %%
# add mean days_burning by state to each row
# add a summary column to a dataframe
fires['mean_days'] = fires.groupby('state')['days_burning'].transform(func='mean')
fires[['state','days_burning','mean_days']].head()
# Out:
#    state  days_burning  mean_days
# 16    CA          15.0   5.387197
# 17    CA           4.0   5.387197
# 25    NM           0.0   6.085806
# 37    NC           1.0   1.015474
# 39    NC           1.0   1.015474

# %%
fires['state_total_days_burning'] = fires.groupby('state')['days_burning'].transform('sum')
fires[['state','days_burning','mean_days','state_total_days_burning']].head()
# Out:
#    state  days_burning  mean_days  state_total_days_burning
# 16    CA          15.0   5.387197                   36272.0
# 17    CA           4.0   5.387197                   36272.0
# 25    NM           0.0   6.085806                   20923.0
# 37    NC           1.0   1.015474                    2100.0
# 39    NC           1.0   1.015474                    2100.0

# %%
fires['days_burning_pct'] = fires['days_burning']/fires['state_total_days_burning']

# %%
fires.head()
# Out:
#        fire_name  fire_year state discovery_date contain_date  acres_burned  \
# 16         Power       2004    CA     2004-10-06   2004-10-21       16823.0
# 17         Freds       2004    CA     2004-10-13   2004-10-17        7700.0
# 25      Bachelor       2004    NM     2004-07-20   2004-07-20          10.0
# 37    Howard Gap       2005    NC     2005-01-27   2005-01-28          50.3
# 39  Austin Creek       2005    NC     2005-02-12   2005-02-13         125.0
#
#    state_obj fire_name_state_obj  fire_name_state  fire_month  days_burning  \
# 16        CA            POWER_CA         POWER_CA          10          15.0
# 17        CA            FREDS_CA         FREDS_CA          10           4.0
# 25        NM         BACHELOR_NM      BACHELOR_NM           7           0.0
# 37        NC       HOWARD GAP_NC    HOWARD GAP_NC           1           1.0
# 39        NC     AUSTIN CREEK_NC  AUSTIN CREEK_NC           2           1.0
#
#     month_burning                     full_name  acres_per_day  mean_days  \
# 16       0.500000         The Power Fire (2004)    1121.533333   5.387197
# 17       0.133333         The Freds Fire (2004)    1925.000000   5.387197
# 25       0.000000      The Bachelor Fire (2004)            inf   6.085806
# 37       0.033333    The Howard Gap Fire (2005)      50.300000   1.015474
# 39       0.033333  The Austin Creek Fire (2005)     125.000000   1.015474
#
#     state_total_days_burning  days_burning_pct
# 16                   36272.0          0.000414
# 17                   36272.0          0.000110
# 25                   20923.0          0.000000
# 37                    2100.0          0.000476
# 39                    2100.0          0.000476

# %% [markdown]
# ### Pandas apply() method: applies functions to rows or columns
#
# * **apply(params)** -> Applies a function to the data in a row or a column and returns a Series.
#
# Parameters:
#
# * **function** -> The function that’s applied to each row or column. It can be a built-in function, a NumPy function, a userdefined function, or a lambda expression.
# * **axis** -> The axis that the function is applied to: axis=0 (the default) for columns and axis=1 for rows.

# %%
# change the format of the percentage column
fires['days_burning_pct'] = fires['days_burning_pct'].apply(lambda x: format(x, '.2%'))
fires.head()
# Out:
#        fire_name  fire_year state discovery_date contain_date  acres_burned  \
# 16         Power       2004    CA     2004-10-06   2004-10-21       16823.0
# 17         Freds       2004    CA     2004-10-13   2004-10-17        7700.0
# 25      Bachelor       2004    NM     2004-07-20   2004-07-20          10.0
# 37    Howard Gap       2005    NC     2005-01-27   2005-01-28          50.3
# 39  Austin Creek       2005    NC     2005-02-12   2005-02-13         125.0
#
#    state_obj fire_name_state_obj  fire_name_state  fire_month  days_burning  \
# 16        CA            POWER_CA         POWER_CA          10          15.0
# 17        CA            FREDS_CA         FREDS_CA          10           4.0
# 25        NM         BACHELOR_NM      BACHELOR_NM           7           0.0
# 37        NC       HOWARD GAP_NC    HOWARD GAP_NC           1           1.0
# 39        NC     AUSTIN CREEK_NC  AUSTIN CREEK_NC           2           1.0
#
#     month_burning                     full_name  acres_per_day  mean_days  \
# 16       0.500000         The Power Fire (2004)    1121.533333   5.387197
# 17       0.133333         The Freds Fire (2004)    1925.000000   5.387197
# 25       0.000000      The Bachelor Fire (2004)            inf   6.085806
# 37       0.033333    The Howard Gap Fire (2005)      50.300000   1.015474
# 39       0.033333  The Austin Creek Fire (2005)     125.000000   1.015474
#
#     state_total_days_burning days_burning_pct
# 16                   36272.0            0.04%
# 17                   36272.0            0.01%
# 25                   20923.0            0.00%
# 37                    2100.0            0.05%
# 39                    2100.0            0.05%

# %% [markdown]
# ### More on apply method

# %%
workData = pd.read_pickle('workData.pkl')
workData.head(3)
# Out:
#     sex  region  wrkstat  hrs1  wkcontct  talkspvs  effctsup
# id
# 2     2       1      1.0  40.0       3.0       4.0       4.0
# 4     2       1      2.0  20.0       1.0       4.0       4.0
# 14    2       2      1.0  37.0       1.0       4.0       3.0

# %%
# apply() method applies a function to the data in a row or a column and returns a Series.
# axis=0 (the default) for columns and axis=1 for rows.
workData['Total'] = workData.apply('sum', axis=1)

# %%
workData.head()
# Out:
#     sex  region  wrkstat  hrs1  wkcontct  talkspvs  effctsup  Total
# id
# 2     2       1      1.0  40.0       3.0       4.0       4.0   55.0
# 4     2       1      2.0  20.0       1.0       4.0       4.0   34.0
# 14    2       2      1.0  37.0       1.0       4.0       3.0   50.0
# 19    1       1      1.0  50.0       1.0       3.0       4.0   61.0
# 21    2       1      1.0  38.0       1.0       4.0       4.0   51.0

# %%
workData.shape
# Out:
# (970, 8)

# %%
# get the mean of each row using a built-in Pandas function
workData.apply('mean')
# Out:
# sex          1.529897
# region       5.184536
# wrkstat      1.163918
# hrs1        42.083505
# wkcontct     2.796907
# talkspvs     3.291753
# effctsup     3.253608
# Total       59.304124
# dtype: float64

# %%
# apply a Numpy function to two columns to get their means
import numpy as np
workData[['sex','hrs1']].apply(np.mean)
# Out:
# sex      1.529897
# hrs1    42.083505
# dtype: float64

# %%
# get the row-wise mean of three columns
workData['avg_rating'] = workData[['wkcontct','talkspvs','effctsup']].apply(np.mean, axis=1)
workData.head(3)
# Out:
#     sex  region  wrkstat  hrs1  wkcontct  talkspvs  effctsup  Total  \
# id
# 2     2       1      1.0  40.0       3.0       4.0       4.0   55.0
# 4     2       1      2.0  20.0       1.0       4.0       4.0   34.0
# 14    2       2      1.0  37.0       1.0       4.0       3.0   50.0
#
#     avg_rating
# id
# 2     3.666667
# 4     3.000000
# 14    2.666667

# %% [markdown]
# ### apply user-defined functions

# %%
def convert_sex(row):
    if row.sex == 1:
        return 'male'
    elif row.sex == 2:
        return 'female'
    else:
        return 'non-binary'
    
workData['sex'] = workData.apply(convert_sex, axis=1)
workData.head()
# Out:
#        sex  region  wrkstat  hrs1  wkcontct  talkspvs  effctsup  Total  \
# id
# 2   female       1      1.0  40.0       3.0       4.0       4.0   55.0
# 4   female       1      2.0  20.0       1.0       4.0       4.0   34.0
# 14  female       2      1.0  37.0       1.0       4.0       3.0   50.0
# 19    male       1      1.0  50.0       1.0       3.0       4.0   61.0
# 21  female       1      1.0  38.0       1.0       4.0       4.0   51.0
#
#     avg_rating
# id
# 2     3.666667
# 4     3.000000
# 14    2.666667
# 19    2.666667
# 21    3.000000

# %% [markdown]
# ### lambda expressions work with DataFrames
#
# * **The if syntax**
#
#     lambda arguments: return_value_if_true if condition
#
# * **The if-else syntax**
#
#     lambda arguments: return_value_if_true if condition else return_value_if_false
#
# * **The if-elif-else syntax**
#
#     lambda arguments: return_value_if_condition_1_true if condition_1 else (return_value_if_condition_2_true if condition_2 else return_value_if_condition_2_false)

# %%
df = pd.DataFrame([[0,1,2],[3,4,5]], columns=['col1','col2','col3'])
df
# Out:
#    col1  col2  col3
# 0     0     1     2
# 1     3     4     5

# %%
df.apply(lambda x: x.sum() * 2, axis=0) # column-wise
# Out:
# col1     6
# col2    10
# col3    14
# dtype: int64

# %%
df.apply(lambda x: x.sum() * 2, axis=1) # row-wise
# Out:
# 0     6
# 1    24
# dtype: int64

# %% [markdown]
# #### How to apply lambda expressions

# %%
# if wrkstat=1.0 replace it with 'full-time' else 'part-time'
workData['wrkstat'] = workData.apply(lambda row: 'full-time' if row.wrkstat == 1.0 else 'part-time', axis=1)
workData.head()
# Out:
#        sex  region    wrkstat  hrs1  wkcontct  talkspvs  effctsup  Total  \
# id
# 2   female       1  full-time  40.0       3.0       4.0       4.0   55.0
# 4   female       1  part-time  20.0       1.0       4.0       4.0   34.0
# 14  female       2  full-time  37.0       1.0       4.0       3.0   50.0
# 19    male       1  full-time  50.0       1.0       3.0       4.0   61.0
# 21  female       1  full-time  38.0       1.0       4.0       4.0   51.0
#
#     avg_rating
# id
# 2     3.666667
# 4     3.000000
# 14    2.666667
# 19    2.666667
# 21    3.000000

# %% [markdown]
# ### What the SettingWithCopyWarning is warning you about

# %%
shots = pd.read_pickle('shot_cleaned.pkl')
shots.set_index('game_id', inplace=True)

# %%
shots.tail()
# Out:
#               player_name  period  minutes_remaining  seconds_remaining  \
# game_id
# 0021801205  Stephen Curry       3                  0                  3
# 0021801215  Stephen Curry       1                  9                 49
# 0021801215  Stephen Curry       1                  8                  1
# 0021801215  Stephen Curry       1                  6                 36
# 0021801215  Stephen Curry       1                  2                 43
#
#              event_type          action_type       shot_type  shot_distance  \
# game_id
# 0021801205    Made Shot  Step Back Jump shot  3PT Field Goal             30
# 0021801215  Missed Shot  Step Back Jump shot  2PT Field Goal             18
# 0021801215    Made Shot            Jump Shot  3PT Field Goal             26
# 0021801215  Missed Shot            Jump Shot  3PT Field Goal             23
# 0021801215    Made Shot            Jump Shot  2PT Field Goal             12
#
#             loc_x  loc_y  shot_attempted_flag  shot_made_flag  game_date  \
# game_id
# 0021801205   -201    224                    1               1 2019-04-07
# 0021801215   -180    -15                    1               0 2019-04-09
# 0021801215     73    255                    1               1 2019-04-09
# 0021801215    132    199                    1               0 2019-04-09
# 0021801215   -129    -15                    1               1 2019-04-09
#
#            home_team visiting_team
# game_id
# 0021801205       GSW           LAC
# 0021801215       NOP           GSW
# 0021801215       NOP           GSW
# 0021801215       NOP           GSW
# 0021801215       NOP           GSW

# %%
df = shots.copy(deep=True)

# %%
df.head(3)
# Out:
#               player_name  period  minutes_remaining  seconds_remaining  \
# game_id
# 0020900015  Stephen Curry       1                 11                 25
# 0020900015  Stephen Curry       1                  9                 31
# 0020900015  Stephen Curry       1                  6                  2
#
#              event_type          action_type       shot_type  shot_distance  \
# game_id
# 0020900015  Missed Shot            Jump Shot  3PT Field Goal             26
# 0020900015    Made Shot  Step Back Jump shot  2PT Field Goal             18
# 0020900015  Missed Shot            Jump Shot  2PT Field Goal             14
#
#             loc_x  loc_y  shot_attempted_flag  shot_made_flag  game_date  \
# game_id
# 0020900015     99    249                    1               0 2009-10-28
# 0020900015   -122    145                    1               1 2009-10-28
# 0020900015    -60    129                    1               0 2009-10-28
#
#            home_team visiting_team
# game_id
# 0020900015       GSW           HOU
# 0020900015       GSW           HOU
# 0020900015       GSW           HOU

# %% [markdown]
# ### Generates the warning and corrupts the data

# %%
dfSlice = df.loc['0020900015',:]        # creates the slice (view)
dfSlice.loc[:,'player_name'] = 'Curry'  # modifies the slice
# Out:
# C:\Users\Vijay Koju\AppData\Local\Temp\ipykernel_18548\4061948481.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfSlice.loc[:,'player_name'] = 'Curry'  # modifies the slice

# %%
df.head(3)
# Out:
#            player_name  period  minutes_remaining  seconds_remaining  \
# game_id
# 0020900015       Curry       1                 11                 25
# 0020900015       Curry       1                  9                 31
# 0020900015       Curry       1                  6                  2
#
#              event_type          action_type       shot_type  shot_distance  \
# game_id
# 0020900015  Missed Shot            Jump Shot  3PT Field Goal             26
# 0020900015    Made Shot  Step Back Jump shot  2PT Field Goal             18
# 0020900015  Missed Shot            Jump Shot  2PT Field Goal             14
#
#             loc_x  loc_y  shot_attempted_flag  shot_made_flag  game_date  \
# game_id
# 0020900015     99    249                    1               0 2009-10-28
# 0020900015   -122    145                    1               1 2009-10-28
# 0020900015    -60    129                    1               0 2009-10-28
#
#            home_team visiting_team
# game_id
# 0020900015       GSW           HOU
# 0020900015       GSW           HOU
# 0020900015       GSW           HOU

# %%
dfSlice.head(3)
# Out:
#            player_name  period  minutes_remaining  seconds_remaining  \
# game_id
# 0020900015       Curry       1                 11                 25
# 0020900015       Curry       1                  9                 31
# 0020900015       Curry       1                  6                  2
#
#              event_type          action_type       shot_type  shot_distance  \
# game_id
# 0020900015  Missed Shot            Jump Shot  3PT Field Goal             26
# 0020900015    Made Shot  Step Back Jump shot  2PT Field Goal             18
# 0020900015  Missed Shot            Jump Shot  2PT Field Goal             14
#
#             loc_x  loc_y  shot_attempted_flag  shot_made_flag  game_date  \
# game_id
# 0020900015     99    249                    1               0 2009-10-28
# 0020900015   -122    145                    1               1 2009-10-28
# 0020900015    -60    129                    1               0 2009-10-28
#
#            home_team visiting_team
# game_id
# 0020900015       GSW           HOU
# 0020900015       GSW           HOU
# 0020900015       GSW           HOU

# %% [markdown]
# Both Dataframes have been modified!

# %% [markdown]
# ### use copy() method to fix this code

# %%
df = shots.copy(deep=True)

# %%
dfSlice = df.loc['0020900015',:].copy()
dfSlice.loc[:,'player_name'] = 'Curry'
df.head(2)
# Out:
#               player_name  period  minutes_remaining  seconds_remaining  \
# game_id
# 0020900015  Stephen Curry       1                 11                 25
# 0020900015  Stephen Curry       1                  9                 31
#
#              event_type          action_type       shot_type  shot_distance  \
# game_id
# 0020900015  Missed Shot            Jump Shot  3PT Field Goal             26
# 0020900015    Made Shot  Step Back Jump shot  2PT Field Goal             18
#
#             loc_x  loc_y  shot_attempted_flag  shot_made_flag  game_date  \
# game_id
# 0020900015     99    249                    1               0 2009-10-28
# 0020900015   -122    145                    1               1 2009-10-28
#
#            home_team visiting_team
# game_id
# 0020900015       GSW           HOU
# 0020900015       GSW           HOU

# %%
dfSlice.head(2)
# Out:
#            player_name  period  minutes_remaining  seconds_remaining  \
# game_id
# 0020900015       Curry       1                 11                 25
# 0020900015       Curry       1                  9                 31
#
#              event_type          action_type       shot_type  shot_distance  \
# game_id
# 0020900015  Missed Shot            Jump Shot  3PT Field Goal             26
# 0020900015    Made Shot  Step Back Jump shot  2PT Field Goal             18
#
#             loc_x  loc_y  shot_attempted_flag  shot_made_flag  game_date  \
# game_id
# 0020900015     99    249                    1               0 2009-10-28
# 0020900015   -122    145                    1               1 2009-10-28
#
#            home_team visiting_team
# game_id
# 0020900015       GSW           HOU
# 0020900015       GSW           HOU

# %% [markdown]
# Only dfSlice Dataframe modified!
